# %%
import pandas as pd 
import numpy as np

# %%
dfins = pd.read_csv(r'C:\Users\ajjup\OneDrive\Desktop\DATASETS\Linear Regression\Big dataset\insurance.csv')

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfins.dtypes
# Out:
# age           int64
# gender       object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
dfins.isna()
# Out:
#         age  gender    bmi  children  smoker  region  charges
# 0     False   False  False     False   False   False    False
# 1     False   False  False     False   False   False    False
# 2     False   False  False     False   False   False    False
# 3     False   False  False     False   False   False    False
# 4     False   False  False     False   False   False    False
# ...     ...     ...    ...       ...     ...     ...      ...
# 1333  False   False  False     False   False   False    False
# 1334  False   False  False     False   False   False    False
# 1335  False   False  False     False   False   False    False
# 1336  False   False  False     False   False   False    False
# 1337  False   False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
dfins.isna().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dfins.dtypes
# Out:
# age           int64
# gender       object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
dfins.dtypes == object
# Out:
# age         False
# gender       True
# bmi         False
# children    False
# smoker       True
# region       True
# charges     False
# dtype: bool

# %%
dfins.dtypes[dfins.dtypes == object].index
# Out:
# Index(['gender', 'smoker', 'region'], dtype='object')

# %%
dfins.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dfins['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dfgen = pd.get_dummies(dfins["gender"], drop_first= True)

# %%
dfgen
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1333     1
# 1334     0
# 1335     0
# 1336     0
# 1337     0
#
# [1338 rows x 1 columns]

# %%
dfins["smoker"]
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
dfins["smoker"].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dfins["smoker"].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
dfins["smoker"].value_counts().plot(kind = "bar")
# Out:
# <AxesSubplot:>

# %%
import seaborn  as sns

# %%
sns.countplot(x='gender', data = dfins)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='smoker', data=dfins)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
dfsmoke = pd.get_dummies(dfins["smoker"], drop_first=True)

# %%
dfsmoke
# Out:
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 1 columns]

# %%
dfins.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
dfins['region']
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %%
dfins["region"].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
dfins['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
sns.countplot(x = "region", data = dfins)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
dfins['region'].value_counts().plot(kind =  'bar')
# Out:
# <AxesSubplot:>

# %%
dfregion = pd.get_dummies(dfins["region"], drop_first=True)

# %%
dfregion
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
dfins["gender"]
# Out:
# 0       female
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 1333      male
# 1334    female
# 1335    female
# 1336    female
# 1337    female
# Name: gender, Length: 1338, dtype: object

# %%
dfgen
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1333     1
# 1334     0
# 1335     0
# 1336     0
# 1337     0
#
# [1338 rows x 1 columns]

# %%
dfins["smoker"]
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: object

# %%
dfsmoke
# Out:
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 1 columns]

# %%
dfins['region']
# Out:
# 0       southwest
# 1       southeast
# 2       southeast
# 3       northwest
# 4       northwest
#           ...
# 1333    northwest
# 1334    northeast
# 1335    southeast
# 1336    southwest
# 1337    northwest
# Name: region, Length: 1338, dtype: object

# %%
dfregion
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
dfcat = dfins[['gender', 'smoker','region']]

# %%
dfcat
# Out:
#       gender smoker     region
# 0     female    yes  southwest
# 1       male     no  southeast
# 2       male     no  southeast
# 3       male     no  northwest
# 4       male     no  northwest
# ...      ...    ...        ...
# 1333    male     no  northwest
# 1334  female     no  northeast
# 1335  female     no  southeast
# 1336  female     no  southwest
# 1337  female    yes  northwest
#
# [1338 rows x 3 columns]

# %%
pd.get_dummies(dfcat)
# Out:
#       gender_female  gender_male  smoker_no  smoker_yes  region_northeast  \
# 0                 1            0          0           1                 0
# 1                 0            1          1           0                 0
# 2                 0            1          1           0                 0
# 3                 0            1          1           0                 0
# 4                 0            1          1           0                 0
# ...             ...          ...        ...         ...               ...
# 1333              0            1          1           0                 0
# 1334              1            0          1           0                 1
# 1335              1            0          1           0                 0
# 1336              1            0          1           0                 0
# 1337              1            0          0           1                 0
#
#       region_northwest  region_southeast  region_southwest
# ...

# %%
pd.get_dummies(dfcat, drop_first= True)
# Out:
#       gender_male  smoker_yes  region_northwest  region_southeast  \
# 0               0           1                 0                 0
# 1               1           0                 0                 1
# 2               1           0                 0                 1
# 3               1           0                 1                 0
# 4               1           0                 1                 0
# ...           ...         ...               ...               ...
# 1333            1           0                 1                 0
# 1334            0           0                 0                 0
# 1335            0           0                 0                 1
# 1336            0           0                 0                 0
# 1337            0           1                 1                 0
#
#       region_southwest
# 0                    1
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...
# ...

# %%
dfgen
# Out:
#       male
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
# ...    ...
# 1333     1
# 1334     0
# 1335     0
# 1336     0
# 1337     0
#
# [1338 rows x 1 columns]

# %%
dfsmoke
# Out:
#       yes
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1333    0
# 1334    0
# 1335    0
# 1336    0
# 1337    1
#
# [1338 rows x 1 columns]

# %%
dfregion
# Out:
#       northwest  southeast  southwest
# 0             0          0          1
# 1             0          1          0
# 2             0          1          0
# 3             1          0          0
# 4             1          0          0
# ...         ...        ...        ...
# 1333          1          0          0
# 1334          0          0          0
# 1335          0          1          0
# 1336          0          0          1
# 1337          1          0          0
#
# [1338 rows x 3 columns]

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
dfins = pd.concat([dfins, dfgen, dfsmoke, dfregion], axis= 1)

# %%
dfins
# Out:
#       age  gender     bmi  children smoker     region      charges  male  yes  \
# 0      19  female  27.900         0    yes  southwest  16884.92400     0    1
# 1      18    male  33.770         1     no  southeast   1725.55230     1    0
# 2      28    male  33.000         3     no  southeast   4449.46200     1    0
# 3      33    male  22.705         0     no  northwest  21984.47061     1    0
# 4      32    male  28.880         0     no  northwest   3866.85520     1    0
# ...   ...     ...     ...       ...    ...        ...          ...   ...  ...
# 1333   50    male  30.970         3     no  northwest  10600.54830     1    0
# 1334   18  female  31.920         0     no  northeast   2205.98080     0    0
# 1335   18  female  36.850         0     no  southeast   1629.83350     0    0
# 1336   21  female  25.800         0     no  southwest   2007.94500     0    0
# 1337   61  female  29.070         0    yes  northwest  29141.36030     0    1
#
# ...

# %%
dfins = dfins.drop(['gender', "smoker", "region"], axis = 1)

# %%
dfins
# Out:
#       age     bmi  children      charges  male  yes  northwest  southeast  \
# 0      19  27.900         0  16884.92400     0    1          0          0
# 1      18  33.770         1   1725.55230     1    0          0          1
# 2      28  33.000         3   4449.46200     1    0          0          1
# 3      33  22.705         0  21984.47061     1    0          1          0
# 4      32  28.880         0   3866.85520     1    0          1          0
# ...   ...     ...       ...          ...   ...  ...        ...        ...
# 1333   50  30.970         3  10600.54830     1    0          1          0
# 1334   18  31.920         0   2205.98080     0    0          0          0
# 1335   18  36.850         0   1629.83350     0    0          0          1
# 1336   21  25.800         0   2007.94500     0    0          0          0
# 1337   61  29.070         0  29141.36030     0    1          1          0
#
#       southwest
# 0             1
# 1             0
# 2             0
# ...

# %%
X = dfins.drop("charges", axis = 1)

# %%
X
# Out:
#       age     bmi  children  male  yes  northwest  southeast  southwest
# 0      19  27.900         0     0    1          0          0          1
# 1      18  33.770         1     1    0          0          1          0
# 2      28  33.000         3     1    0          0          1          0
# 3      33  22.705         0     1    0          1          0          0
# 4      32  28.880         0     1    0          1          0          0
# ...   ...     ...       ...   ...  ...        ...        ...        ...
# 1333   50  30.970         3     1    0          1          0          0
# 1334   18  31.920         0     0    0          0          0          0
# 1335   18  36.850         0     0    0          0          1          0
# 1336   21  25.800         0     0    0          0          0          1
# 1337   61  29.070         0     0    1          1          0          0
#
# [1338 rows x 8 columns]

# %%
y = dfins["charges"]

# %%
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest  = train_test_split(X,y, test_size=0.20)

# %%
Xtrain.shape,Xtest.shape,  X.shape
# Out:
# ((1070, 8), (268, 8), (1338, 8))

# %%
ytrain.shape,ytest.shape,y.shape
# Out:
# ((1070,), (268,), (1338,))

# %% [markdown]
# ###   Building Model

# %%
from sklearn.linear_model import LinearRegression

# %%
LRmodel = LinearRegression()

# %%
LRmodel
# Out:
# LinearRegression()

# %%
LRmodel.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
LRmodel.coef_
# Out:
# array([  254.78442039,   321.93483252,   440.86756048,  -319.32071732,
#        23353.90645095,  -503.28779091,  -942.82155919, -1134.403079  ])

# %%
LRmodel.intercept_
# Out:
# -11094.80780350035

# %%
LRmodel.score(Xtest, ytest)
# Out:
# 0.808719674471605
