# %%
import pandas as pd

# %%
import numpy as np

# %%
dftitanic = pd.read_csv(r"C:\Users\ajjup\OneDrive\Desktop\DATASETS\Classification\Logistic Regression\titanic.csv")

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
dftitanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
dftitanic.drop(['PassengerId', 'Name','Ticket', 'Fare', 'Cabin'], axis = 1, inplace=True)

# %%
dftitanic
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
dftitanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Gender       object
# Age         float64
# SibSp         int64
# Parch         int64
# Embarked     object
# dtype: object

# %%
dftitanic["Gender"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Gender, Length: 891, dtype: object

# %%
dfgen = pd.get_dummies(dftitanic["Gender"], drop_first=True)

# %%
dfgen
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
dftitanic["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
dftitanic["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
dftitanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
dftitanic.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Gender        0
# Age         177
# SibSp         0
# Parch         0
# Embarked      2
# dtype: int64

# %%
dftitanic['Embarked'] = dftitanic["Embarked"].fillna("S")

# %%
dftitanic
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
dftitanic.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Gender        0
# Age         177
# SibSp         0
# Parch         0
# Embarked      0
# dtype: int64

# %%
dftitanic['Age'].isna().sum()
# Out:
# 177

# %%
m = np.round(dftitanic["Age"].mean())

# %%
m
# Out:
# 30.0

# %%
dftitanic["Age"] = dftitanic['Age'].fillna(m)

# %%
dftitanic.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64

# %%
dftitanic["Embarked"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
dftitanic.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Gender      0
# Age         0
# SibSp       0
# Parch       0
# Embarked    0
# dtype: int64

# %%
dftitanic.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Gender       object
# Age         float64
# SibSp         int64
# Parch         int64
# Embarked     object
# dtype: object

# %%
dfembark = pd.get_dummies(dftitanic["Embarked"], drop_first=True)

# %%
dfgen
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
dfembark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
dftitanic  = pd.concat([dftitanic, dfgen, dfembark], axis = 1)

# %%
dftitanic
# Out:
#      Survived  Pclass  Gender   Age  SibSp  Parch Embarked  male  Q  S
# 0           0       3    male  22.0      1      0        S     1  0  1
# 1           1       1  female  38.0      1      0        C     0  0  0
# 2           1       3  female  26.0      0      0        S     0  0  1
# 3           1       1  female  35.0      1      0        S     0  0  1
# 4           0       3    male  35.0      0      0        S     1  0  1
# ..        ...     ...     ...   ...    ...    ...      ...   ... .. ..
# 886         0       2    male  27.0      0      0        S     1  0  1
# 887         1       1  female  19.0      0      0        S     0  0  1
# 888         0       3  female  30.0      1      2        S     0  0  1
# 889         1       1    male  26.0      0      0        C     1  0  0
# 890         0       3    male  32.0      0      0        Q     1  1  0
#
# [891 rows x 10 columns]

# %%
dftitanic.drop(["Embarked", "Gender"], axis = 1, inplace= True)

# %%
dftitanic
# Out:
#      Survived  Pclass   Age  SibSp  Parch  male  Q  S
# 0           0       3  22.0      1      0     1  0  1
# 1           1       1  38.0      1      0     0  0  0
# 2           1       3  26.0      0      0     0  0  1
# 3           1       1  35.0      1      0     0  0  1
# 4           0       3  35.0      0      0     1  0  1
# ..        ...     ...   ...    ...    ...   ... .. ..
# 886         0       2  27.0      0      0     1  0  1
# 887         1       1  19.0      0      0     0  0  1
# 888         0       3  30.0      1      2     0  0  1
# 889         1       1  26.0      0      0     1  0  0
# 890         0       3  32.0      0      0     1  1  0
#
# [891 rows x 8 columns]

# %%
X = dftitanic.drop("Survived", axis = 1)

# %%
X
# Out:
#      Pclass   Age  SibSp  Parch  male  Q  S
# 0         3  22.0      1      0     1  0  1
# 1         1  38.0      1      0     0  0  0
# 2         3  26.0      0      0     0  0  1
# 3         1  35.0      1      0     0  0  1
# 4         3  35.0      0      0     1  0  1
# ..      ...   ...    ...    ...   ... .. ..
# 886       2  27.0      0      0     1  0  1
# 887       1  19.0      0      0     0  0  1
# 888       3  30.0      1      2     0  0  1
# 889       1  26.0      0      0     1  0  0
# 890       3  32.0      0      0     1  1  0
#
# [891 rows x 7 columns]

# %%
y = dftitanic['Survived']

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X,y, test_size=0.20, random_state=42)

# %%
Xtrain.shape, Xtest.shape, X.shape
# Out:
# ((712, 7), (179, 7), (891, 7))

# %%
ytrain.shape,ytest.shape, y.shape
# Out:
# ((712,), (179,), (891,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
lrmodel = LogisticRegression()

# %%
lrmodel.fit(Xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
lrmodel.score(Xtest, ytest)
# Out:
# 0.8100558659217877

# %%
# DT, KNN, Logreg, svm,
